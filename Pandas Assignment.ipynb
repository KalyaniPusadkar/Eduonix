# %% [markdown]
# # LOAD THE DATASET FROM THE GIVEN BELOW LINK.

# %% [markdown]
# https://drive.google.com/file/d/1RWvyhf9AcDZsSB5xVVgzsbHI1m4sFBJf/view?usp=share_link

# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\kalya\Downloads\chipotle - chipotle.csv",index_col=0,header=0)

# %%
df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN      $2.39
# 1                                              [Clementine]      $3.39
# ...

# %% [markdown]
# # USING PANDAS FUNCTION CALCULATE HOW MANY PRODUCTS COSTS MORE THAN $10?

# %%
df.dtypes
# Out:
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price'] = df['item_price'].str[1:].astype(float)
df['Per Item Price'] = df['item_price']/df['quantity']

# %%
df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description  item_price  \
# order_id
# 1                                                       NaN        2.39
# 1                                              [Clementine]        3.39
# ...

# %%
item_above10= df.loc[(df['Per Item Price']>=10)]

# %%
item_above10
# Out:
#           quantity           item_name  \
# order_id
# 3                1        Chicken Bowl
# 4                1       Steak Burrito
# 7                1        Chicken Bowl
# 12               1     Chicken Burrito
# 19               1       Barbacoa Bowl
# ...            ...                 ...
# 1830             1       Steak Burrito
# 1830             1      Veggie Burrito
# 1833             1       Steak Burrito
# 1833             1       Steak Burrito
# 1834             1  Chicken Salad Bowl
#
#                                          choice_description  item_price  \
# order_id
# 3         [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4         [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 7         [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 12        [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 19        [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# ...

# %%
item_above10.count().max()
# Out:
# 1034

# %% [markdown]
# # What is the price of each item?

# %%
df1 =df[['item_name','Per Item Price']]
df1
# Out:
#                                       item_name  Per Item Price
# order_id
# 1                  Chips and Fresh Tomato Salsa            2.39
# 1                                          Izze            3.39
# 1                              Nantucket Nectar            3.39
# 1         Chips and Tomatillo-Green Chili Salsa            2.39
# 2                                  Chicken Bowl            8.49
# ...                                         ...             ...
# 1833                              Steak Burrito           11.75
# 1833                              Steak Burrito           11.75
# 1834                         Chicken Salad Bowl           11.25
# 1834                         Chicken Salad Bowl            8.75
# 1834                         Chicken Salad Bowl            8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# # Which is the Most Expensive Item?

# %%
df2= df.nlargest(1, columns= ['item_price'])
df2
# Out:
#           quantity                     item_name choice_description  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa                NaN
#
#           item_price  Per Item Price
# order_id
# 1443           44.25            2.95
